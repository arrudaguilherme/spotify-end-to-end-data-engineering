# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="976216012d274a7b803cf5dd2433dd47",
                                                      client_secret="e2ff0790ad674220b6066e1b1843efb6")

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlists = sp.user("spotify")

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF"

# %%
playlist_URI = playlist_link.split("/")[4]

# %%
data = sp.playlist_tracks(playlist_URI)
print(data)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF/tracks?offset=0&limit=100&additional_types=track', 'items': [{'added_at': '2024-02-29T10:53:41Z', 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'}, 'href': 'https://api.spotify.com/v1/users/', 'id': '', 'type': 'user', 'uri': 'spotify:user:'}, 'is_local': False, 'primary_color': None, 'track': {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'}, 'href': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET', 'id': '22wbnEMDvgVIAGdFeek6ET', 'name': 'Benson Boone', 'type': 'artist', 'uri': 'spotify:artist:22wbnEMDvgVIAGdFeek6ET'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/29aSKB1qPEbN0Qf9OPSQpw'}, 'href': 'https://api.spotify.com/v1/albums/29aSKB1qPEbN0Qf9OPSQpw', 'id': '29aSKB1qPEbN0Qf9OPSQpw', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273f2a919d3fa0f2b2593c92d19', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02f2a919d3fa0f2b2593c92d19', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851f2a919d3fa0f2b2593c92d19', 'width': 64}], 'name': 'Beautiful Things', 'release_date': '2024-01-18', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:29aSKB1qPEbN0Qf9OPSQpw'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'}, 'href': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET', 'id': '22wbnEMDvgVIAGdFeek6ET', 'name': 'Benson Boone', 'type': 'artist', 'uri': 'spotify:artist:22wbnEMDvgVIAGdFeek6ET'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'disc_number': 1, 'duration_ms': 180304, 'episode': F ...

# %%
data["items"][0]["track"]["album"]["id"]
# Out:
# '29aSKB1qPEbN0Qf9OPSQpw'

# %%
data["items"][0]["track"]["album"]["name"]
# Out:
# 'Beautiful Things'

# %%
data["items"][0]["track"]["album"]["release_date"]
# Out:
# '2024-01-18'

# %%
data["items"][0]["track"]["album"]["total_tracks"]
# Out:
# 1

# %%
data["items"][0]["track"]["album"]["external_urls"]["spotify"]
# Out:
# 'https://open.spotify.com/album/29aSKB1qPEbN0Qf9OPSQpw'

# %%
data["items"][0]["track"]["album"]["artists"][0]["name"]
# Out:
# 'Benson Boone'

# %%
album_list = []
for row in data["items"]:
    album_id = row["track"]["album"]["id"]
    album_name = row["track"]["album"]["name"]
    album_release_date = row["track"]["album"]["release_date"]
    album_total_tracks = row["track"]["album"]["total_tracks"]
    album_url = row["track"]["album"]["external_urls"]["spotify"]
    
    album_element = {"album_id":album_id,
                     "album_name":album_name,
                     "release_date":album_release_date,
                     "album_total_tracks":album_total_tracks,
                     "album_url":album_url
                    }
    album_list.append(album_element)

# %%
artist_list = []
for row in data["items"]:
    for key, value in row.items():
        if key == "track":
            for artist in value["artists"]:
                artist_dict = {"artist_id":artist["id"],
                            "artist_name":artist["name"],
                            "external_url":artist["href"]
                            }
                artist_list.append(artist_dict)

# %%
song_list = []
for row in data["items"]:
    song_id = row["track"]["id"]
    song_name = row["track"]["name"]
    song_duration = row["track"]["duration_ms"]
    song_url = row["track"]["external_urls"]["spotify"]
    song_popularity = row["track"]["popularity"]
    song_added = row["added_at"]
    album_id = row["track"]["album"]["id"]
    artist_id = row["track"]["album"]["artists"][0]["id"]
    song_element = {"song_id":song_id,
                    "song_name":song_name,
                    "duration_ms":song_duration,
                    "url":song_url,
                    "song_popularity":song_popularity,
                    "song_added":song_added,
                    "album_id":album_id,
                    "artist_id":artist_id
                    }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)
artist_df = pd.DataFrame.from_dict(artist_list)
song_df = pd.DataFrame.from_dict(song_list)

# %%
album_df = album_df.drop_duplicates(subset=["album_id"])

# %%
artist_df = artist_df.drop_duplicates(subset=["artist_id"])

# %%
song_df = song_df.drop_duplicates(subset=["song_id"])

# %%
album_df["release_date"] = pd.to_datetime(album_df["release_date"])

# %%
song_df["song_added"] = pd.to_datetime(song_df["song_added"])

# %%
artist_df
# Out:
#                  artist_id          artist_name  \
# 0   22wbnEMDvgVIAGdFeek6ET         Benson Boone
# 1   4xPQFgDA5M2xa0ZGo5iIsv                   ¥$
# 2   5K4W6rqBFWDnAN6FQUkS6x           Kanye West
# 3   7c0XG5cIJTrrAgEC3ULPiq        Ty Dolla $ign
# 4   1pPmIToKXyGdsCF6LmqLmI         Rich The Kid
# 5   699OTQXzgjhIYAHMy9RyPD        Playboi Carti
# 6   6vWDO969PvNqNYHIOW5v0m              Beyoncé
# 7   45dkTj5sMRSjrmBSBeiHym           Tate McRae
# 8   06HL4z0CvFAxyc27GXpf02         Taylor Swift
# 9   33qOK5uJ8AR2xuQQAhHump          Teddy Swims
# 10  5p9HO3XC5P3BLxJs5Mtrhm                  Djo
# 11  1Xyo4u8uXC1ZmMpatF05PJ           The Weeknd
# 12  250b0Wlc5Vk0CoUsaCY84M               JENNIE
# 13  1pBLC0qVRTB5zVMuteQ9jJ       Lily-Rose Depp
# 14  3Me35AWHCGqW4sZ7bWWJt1                 Xavi
# 15  2RQXRUsr4IW1f3mKyKsy4B           Noah Kahan
# 16  2uYWxilOVlUdk4oV9DvwqK               Mitski
# 17  1URnnhqYAYcrqrcwql10ft            21 Savage
# 18  0n4Fao9kbjgM76RmVlfSwr            YG Marley
# 19  2LRoIwlKmHjgvigdNGBHNo                 Feid
# 20  7jAs1uPnpfNmT6e5qtEPxq            ATL Jacob
# 21  2LIk90788K0zvyj2JJVwkJ          Jack Harlow
# 22  7o95ZoZt5ZYn31e9z1Hc0a  Natasha Bedingfield
# 23  7tYKF4w9nC0nq9CsPZTHyP                  SZA
# 24  7Ln80lUS6He07XvHI8qqHH       Arctic Monkeys
# 25  7CvTknweLr9feJtRGrpDBy           FloyyMenor
# 26  1Yj5Xey7kTwvZla8sqdsdE              Cris Mj
# 28  6M2wZ9GZgrQXHCFfjv46we             Dua Lipa
# 31  6tbjWDEIzxoDsBA1FuhfPW              Madonna
# 33  6ltzsmQQbmdoHHbLZ4ZN25           Lord Huron
# 34  7iK8PXO48WeuP03g8YR51W          Myke Towers
# 35  4q3ewBCX7sLwd24euuV69X            Bad Bunny
# 37  6HaGTQPmzraVmaVxvz6EUc            Jung Kook
# 38  3MdXrJWsbVzdn6fe5JYkSQ                Latto
# 39  66CXWjxzNUsdJxJ2JdwvnR        Ariana Grande
# 40  1McMsnEElThX1knmY4oliG       Olivia Rodrigo
# 42  4tZwfgrHOc3mvqYlEYSvVi            Daft Punk
# 43  7uMDnSZyUYNBPLhPMNuaM2          Kenya Grace
# 44  0Y5tJX1MQlPlqiwlOH1tJY         Travis Scott
# 46  790FomKkXshlbRYZFtlgla              KAROL G
# 47  12GqGscKJx3aE4t07u7eVZ           Peso Pluma
# 48  5YGY8feqx7naU7z4HrwZM6          Miley Cyrus
# 49  10exVja0key0uqUkk6LJRT            Vance Joy
# 51  40ZNYROS4zLfyyBSs2PGe2           Zach Bryan
# 52  70kkdajctXSbqSMJbQO424      Kacey Musgraves
# 53  3SozjO3Lat463tQICI9LcE                 Tyla
# 54  0du5cEVh5yTK9QJze8zA0C           Bruno Mars
# 55  33NVpKoXjItPwUJTMZIOiY        David Kushner
# 56  5cj0lLjcoR7YOSnhnX0Po5             Doja Cat
# 57  1U1el3k54VvEUzo3ybLPlM           Kali Uchis
# 62  6qqNVTkY8uBg9cP3Jd7DAH        Billie Eilish
# 63  08PvCOlef4xdOr20jFSTPd            Flo Milli
# 65  2o5jDhtHVPhrJdv3cEQ99Z               Tiësto
# 66  6KImCVD70vtIoJWnq6nGn3         Harry Styles
# 68  74KM79TiuVKeVCqs8QtB0B    Sabrina Carpenter
# 70  7FNnA9vBm6EKceENgCGRMb               Anitta
#
#                                          external_url
# 0   https://api.spotify.com/v1/artists/22wbnEMDvgV...
# 1   https://api.spotify.com/v1/artists/4xPQFgDA5M2...
# 2   https://api.spotify.com/v1/artists/5K4W6rqBFWD...
# 3   https://api.spotify.com/v1/artists/7c0XG5cIJTr...
# 4   https://api.spotify.com/v1/artists/1pPmIToKXyG...
# 5   https://api.spotify.com/v1/artists/699OTQXzgjh...
# 6   https://api.spotify.com/v1/artists/6vWDO969PvN...
# 7   https://api.spotify.com/v1/artists/45dkTj5sMRS...
# 8   https://api.spotify.com/v1/artists/06HL4z0CvFA...
# 9   https://api.spotify.com/v1/artists/33qOK5uJ8AR...
# 10  https://api.spotify.com/v1/artists/5p9HO3XC5P3...
# 11  https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 12  https://api.spotify.com/v1/artists/250b0Wlc5Vk...
# 13  https://api.spotify.com/v1/artists/1pBLC0qVRTB...
# 14  https://api.spotify.com/v1/artists/3Me35AWHCGq...
# 15  https://api.spotify.com/v1/artists/2RQXRUsr4IW...
# 16  https://api.spotify.com/v1/artists/2uYWxilOVlU...
# 17  https://api.spotify.com/v1/artists/1URnnhqYAYc...
# 18  https://api.spotify.com/v1/artists/0n4Fao9kbjg...
# 19  https://api.spotify.com/v1/artists/2LRoIwlKmHj...
# 20  https://api.spotify.com/v1/artists/7jAs1uPnpfN...
# 21  https://api.spotify.com/v1/artists/2LIk90788K0...
# 22  https://api.spotify.com/v1/artists/7o95ZoZt5ZY...
# 23  https://api.spotify.com/v1/artists/7tYKF4w9nC0...
# 24  https://api.spotify.com/v1/artists/7Ln80lUS6He...
# 25  https://api.spotify.com/v1/artists/7CvTknweLr9...
# 26  https://api.spotify.com/v1/artists/1Yj5Xey7kTw...
# 28  https://api.spotify.com/v1/artists/6M2wZ9GZgrQ...
# 31  https://api.spotify.com/v1/artists/6tbjWDEIzxo...
# 33  https://api.spotify.com/v1/artists/6ltzsmQQbmd...
# 34  https://api.spotify.com/v1/artists/7iK8PXO48We...
# 35  https://api.spotify.com/v1/artists/4q3ewBCX7sL...
# 37  https://api.spotify.com/v1/artists/6HaGTQPmzra...
# 38  https://api.spotify.com/v1/artists/3MdXrJWsbVz...
# 39  https://api.spotify.com/v1/artists/66CXWjxzNUs...
# 40  https://api.spotify.com/v1/artists/1McMsnEElTh...
# 42  https://api.spotify.com/v1/artists/4tZwfgrHOc3...
# 43  https://api.spotify.com/v1/artists/7uMDnSZyUYN...
# 44  https://api.spotify.com/v1/artists/0Y5tJX1MQlP...
# 46  https://api.spotify.com/v1/artists/790FomKkXsh...
# 47  https://api.spotify.com/v1/artists/12GqGscKJx3...
# 48  https://api.spotify.com/v1/artists/5YGY8feqx7n...
# 49  https://api.spotify.com/v1/artists/10exVja0key...
# 51  https://api.spotify.com/v1/artists/40ZNYROS4zL...
# 52  https://api.spotify.com/v1/artists/70kkdajctXS...
# 53  https://api.spotify.com/v1/artists/3SozjO3Lat4...
# 54  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 55  https://api.spotify.com/v1/artists/33NVpKoXjIt...
# 56  https://api.spotify.com/v1/artists/5cj0lLjcoR7...
# 57  https://api.spotify.com/v1/artists/1U1el3k54Vv...
# 62  https://api.spotify.com/v1/artists/6qqNVTkY8uB...
# 63  https://api.spotify.com/v1/artists/08PvCOlef4x...
# 65  https://api.spotify.com/v1/artists/2o5jDhtHVPh...
# 66  https://api.spotify.com/v1/artists/6KImCVD70vt...
# 68  https://api.spotify.com/v1/artists/74KM79TiuVK...
# 70  https://api.spotify.com/v1/artists/7FNnA9vBm6E...
